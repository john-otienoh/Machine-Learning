# %% [markdown]
# # Time Series Analysis Using XGBoost

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# %% [markdown]
# ## Import the data

# %%
df = pd.read_excel("./Telco_customer_churn.xlsx")
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.drop(['Churn Reason', 'CLTV', 'Churn Label', 'Churn Score'], axis=1, inplace=True)
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...
#
#   Device Protection Tech Support Streaming TV  Streaming Movies  \
# 0                No           No           No                No
# ...

# %% [markdown]
# ## Check for Unique Values

# %%
for u in df.columns:
    print(f"Column {u} - {df[u].unique()}")
# Out:
# Column CustomerID - ['3668-QPYBK' '9237-HQITU' '9305-CDSKC' ... '2234-XADUH' '4801-JZAZL'
#  '3186-AJIEK']
# Column Count - [1]
# Column Country - ['United States']
# Column State - ['California']
# Column City - ['Los Angeles' 'Beverly Hills' 'Huntington Park' ... 'Standish' 'Tulelake'
#  'Olympic Valley']
# Column Zip Code - [90003 90005 90006 ... 96128 96134 96146]
# Column Lat Long - ['33.964131, -118.272783' '34.059281, -118.30742' '34.048013, -118.293953'
#  ... '40.346634, -120.386422' '41.813521, -121.492666'
#  '39.191797, -120.212401']
# Column Latitude - [33.964131 34.059281 34.048013 ... 40.346634 41.813521 39.191797]
# Column Longitude - [-118.272783 -118.30742  -118.293953 ... -120.386422 -121.492666
#  -120.212401]
# Column Gender - ['Male' 'Female']
# Column Senior Citizen - ['No' 'Yes']
# Column Partner - ['No' 'Yes']
# Column Dependents - ['No' 'Yes']
# Column Tenure Months - [ 2  8 28 49 10  1 47 17  5 34 11 15 18  9  7 12 25 68 55 37  3 27 20  4
# ...

# %%
df.drop(['Count', 'Country', 'State', 'CustomerID', 'Lat Long'], axis=1, inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %% [markdown]
# ## XGBoost Trees

# %%
df.replace(' ', '_', regex=True, inplace=True)
df['City'].unique()[0:10]
# Out:
# array(['Los_Angeles', 'Beverly_Hills', 'Huntington_Park', 'Lynwood',
#        'Marina_Del_Rey', 'Inglewood', 'Santa_Monica', 'Torrance',
#        'Whittier', 'La_Habra'], dtype=object)

# %%
df.columns = df.columns.str.replace(' ', '_', regex=True)
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ## Missing Values

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df['Phone_Service'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Total_Charges'].unique()
# df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])
# Out:
# array([108.15, 151.65, 820.5, ..., 7362.9, 346.45, 6844.5],
#       shape=(6531,), dtype=object)

# %% [markdown]
# ## Dealing with Missing Data

# %%
len(df.loc[df['Total_Charges'] == '_'])
# Out:
# 11

# %%
df.loc[(df['Total_Charges'] == '_'), 'Total_Charges'] = 0

# %%
df.loc[df['Tenure_Months'] == 0]
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %% [markdown]
# ## Format Data(Dependent and dependent variable)

# %%
X = df.drop('Churn_Value', axis=1).copy()
X.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Online_Backup  \
# 0      No         No              2           Yes  ...           Yes
# 1      No        Yes              2           Yes  ...            No
# 2      No        Yes              8           Yes  ...            No
# 3     Yes        Yes             28           Yes  ...            No
# 4      No        Yes             49           Yes  ...           Yes
#
#   Device_Protection Tech_Support Streaming_TV Streaming_Movies  \
# ...

# %%
y = df['Churn_Value'].copy()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn_Value, dtype: int64

# %% [markdown]
# ## One-Hot Encoding
# get_dummies( )/ColumnTransfer( )

# %%
X.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# dtype: object

# %%
pd.get_dummies(X, columns=['Payment_Method']).head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Streaming_TV  \
# 0      No         No              2           Yes  ...           No
# 1      No        Yes              2           Yes  ...           No
# 2      No        Yes              8           Yes  ...          Yes
# 3     Yes        Yes             28           Yes  ...          Yes
# 4      No        Yes             49           Yes  ...          Yes
#
#   Streaming_Movies        Contract Paperless_Billing Monthly_Charges  \
# ...

# %%
X_encoded = pd.get_dummies(X, columns=['City',
                                       'Gender',
                                       'Senior_Citizen',
                                       'Partner',
                                       'Dependents',
                                       'Phone_Service',
                                       'Multiple_Lines',
                                       'Internet_Service',
                                       'Online_Security',
                                       'Online_Backup',
                                       'Device_Protection',
                                       'Tech_Support',
                                       'Streaming_TV',
                                       'Streaming_Movies',
                                       'Contract',
                                       'Paperless_Billing',
                                       'Payment_Method'                                 
])
X_encoded.head()
# Out:
#    Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0     90003  33.964131 -118.272783              2            53.85
# 1     90005  34.059281 -118.307420              2            70.70
# 2     90006  34.048013 -118.293953              8            99.65
# 3     90010  34.062125 -118.315709             28           104.80
# 4     90015  34.039224 -118.266293             49           103.70
#
#    Total_Charges  City_Acampo  City_Acton  City_Adelanto  City_Adin  ...  \
# 0         108.15        False       False          False      False  ...
# 1         151.65        False       False          False      False  ...
# 2         820.50        False       False          False      False  ...
# 3        3046.05        False       False          False      False  ...
# 4        5036.30        False       False          False      False  ...
#
#    Streaming_Movies_Yes  Contract_Month-to-month  Contract_One_year  \
# ...

# %%
y.unique()
# Out:
# array([1, 0])

# %% [markdown]
# ## Building Model

# %%
sum(y)/len(y) * 100
# Out:
# 26.536987079369588

# %%
X_train, X_test,  y_train, y_test = train_test_split(X_encoded, y, random_state=42, stratify=y)

# %%
sum(y_train)/len(y_train) * 100
# Out:
# 26.54297614539947

# %%
sum(y_test)/len(y_test) * 100
# Out:
# 26.519023282226005

# %%
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    missing=None,
    seed=42,
    gamma=0.25,
    learning_rate=0.1,
    max_depth=4,
    scale_pos_weight=3,
    subsample=0.9,
    colsample_bytree=0.5,
)

xgb_model.fit(
    X_train, 
    y_train,
    eval_set=[(X_test, y_test)],
    # eval_metric="aucpr",
    verbose=True
)
# Out:
# [0]	validation_0-logloss:0.67783
# [1]	validation_0-logloss:0.64933
# [2]	validation_0-logloss:0.62665
# [3]	validation_0-logloss:0.60735
# [4]	validation_0-logloss:0.59029
# [5]	validation_0-logloss:0.57509
# [6]	validation_0-logloss:0.56220
# [7]	validation_0-logloss:0.55105
# [8]	validation_0-logloss:0.54151
# [9]	validation_0-logloss:0.53393
# [10]	validation_0-logloss:0.52690
# [11]	validation_0-logloss:0.51982
# [12]	validation_0-logloss:0.51483
# [13]	validation_0-logloss:0.51019
# [14]	validation_0-logloss:0.50638
# [15]	validation_0-logloss:0.50305
# [16]	validation_0-logloss:0.50066
# [17]	validation_0-logloss:0.49783
# [18]	validation_0-logloss:0.49460
# [19]	validation_0-logloss:0.49181
# [20]	validation_0-logloss:0.48980
# [21]	validation_0-logloss:0.48775
# [22]	validation_0-logloss:0.48571
# [23]	validation_0-logloss:0.48385
# [24]	validation_0-logloss:0.48246
# [25]	validation_0-logloss:0.48163
# [26]	validation_0-logloss:0.48063
# [27]	validation_0-logloss:0.47925
# ...

# %%
# plot_confusion_matrix(
#     xgb_model,
#     X_test,
#     y_test,
#     values_format='d',
#     display_labels=['Did not Leave', 'Left']
# )
disp = ConfusionMatrixDisplay(confusion_matrix=xgb_model, display_labels=['Did not Leave', 'Left'])
disp.plot(values_format='d', cmap='Blues')
plt.title('XGBoost Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 9
#       1 # plot_confusion_matrix(
#       2 #     xgb_model,
#       3 #     X_test,
#    (...)      6 #     display_labels=['Did not Leave', 'Left']
#       7 # )
#       8 disp = ConfusionMatrixDisplay(confusion_matrix=xgb_model, display_labels=['Did not Leave', 'Left'])
# ----> 9 disp.plot(values_format='d', cmap='Blues')
#      10 plt.title('XGBoost Confusion Matrix')
#      11 plt.show()
#
# File ~/outis_codes/Tech_Boy/Machine-Learning/.venv/lib/python3.12/site-packages/sklearn/metrics/_plot/confusion_matrix.py:145, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     142     fig = ax.figure
#     144 cm = self.confusion_matrix
# --> 145 n_classes = cm.shape[0]
#     147 default_im_kw = dict(interpolation="nearest", cmap=cmap)
# ...
